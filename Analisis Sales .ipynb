# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df1=pd.read_csv('supermarket_sales - Sheet1.csv')

# %%
df1
# Out:
#       Invoice ID Branch       City Customer type  Gender            Product line  Unit price  Quantity   Tax 5%      Total       Date   Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0    750-67-8428      A     Yangon        Member  Female       Health and beauty       74.69         7  26.1415   548.9715 2019-01-01  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1    226-31-3081      C  Naypyitaw        Normal  Female  Electronic accessories       15.28         5   3.8200    80.2200 2019-01-01  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2    631-41-3108      A     Yangon        Normal    Male      Home and lifestyle       46.33         7  16.2155   340.5255 2019-01-01  13:23  Credit card  324.31                 4.761905       16.2155     7.4
# ...

# %%
df1['Date']=sorted(df1['Date'])

# %%
df1['Date'].min()
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
df1['Date'].max()
# Out:
# Timestamp('2019-03-30 00:00:00')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %%
print('Mean of Total Rating:',df1['Rating'].mean())
print('Total Sales:',df1['Total'].sum())
print('Total Cost of Good Sold:',df1['cogs'].sum())
print('Total Gross Income:',df1['gross income'].sum())
print('Total Tax:',df1['Tax 5%'].sum())
print('Gross Margin Percentage:',df1['gross margin percentage'].mean(),'%')
# Out:
# Mean of Total Rating: 6.972700000000003
# Total Sales: 322966.74899999995
# Total Cost of Good Sold: 307587.38
# Total Gross Income: 15379.368999999999
# Total Tax: 15379.368999999999
# Gross Margin Percentage: 4.761904762000062 %

# %%
df1['Product line'].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %%
fashion=df1.loc[df1['Product line']=='Fashion accessories']
food=df1.loc[df1['Product line']=='Food and beverages']
electronics=df1.loc[df1['Product line']=='Electronic accessories']
sports=df1.loc[df1['Product line']=='Sports and travel']
home=df1.loc[df1['Product line']=='Home and lifestyle']
health=df1.loc[df1['Product line']=='Health and beauty ']

# %%
print('Total Sales Quantity in Fashion Accessories:',fashion.Quantity.sum())
print('Total Sales Quantity in Food and Beverages:',food.Quantity.sum())
print('Total Sales Quantity in Electronic Accessories :',electronics.Quantity.sum())
print('Total Sales Quantity in Sports and Travel:',sports.Quantity.sum())
print('Total Sales Quantity in Home and Lifestyle:',home.Quantity.sum())
print('Total Sales Quantity in Health and Beauty :',health.Quantity.sum())
# Out:
# Total Sales Quantity in Fashion Accessories: 902
# Total Sales Quantity in Food and Beverages: 952
# Total Sales Quantity in Electronic Accessories : 971
# Total Sales Quantity in Sports and Travel: 920
# Total Sales Quantity in Home and Lifestyle: 911
# Total Sales Quantity in Health and Beauty : 0

# %%
df1['City'].value_counts()
# Out:
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: City, dtype: int64

# %%
yangon=df1.loc[df1['City']=='Yangon']
mandalay=df1.loc[df1['City']=='Mandalay']
naypyitaw=df1.loc[df1['City']=='Naypyitaw']

# %%
print('Mean of Total Rating in Yangon:',yangon['Rating'].mean())
print('Total Sales in Yangon:',yangon['Total'].sum())
print('Total Cost of Good Sold in Yangon:',yangon['cogs'].sum())
print('Total Gross Income in Yangon:',yangon['gross income'].sum())
print('Total Tax in Yangon:',yangon['Tax 5%'].sum())
print('Gross Margin Percentage in Yangon:',yangon['gross margin percentage'].mean(),'%')
# Out:
# Mean of Total Rating in Yangon: 7.027058823529413
# Total Sales in Yangon: 106200.3705
# Total Cost of Good Sold in Yangon: 101143.20999999999
# Total Gross Income in Yangon: 5057.1605
# Total Tax in Yangon: 5057.1605
# Gross Margin Percentage in Yangon: 4.761904762000018 %

# %%
print('Mean of Total Rating in Mandalay:',mandalay['Rating'].mean())
print('Total Sales in Mandalay:',mandalay['Total'].sum())
print('Total Cost of Good Sold in Mandalay:',mandalay['cogs'].sum())
print('Total Gross Income in Mandalay:',mandalay['gross income'].sum())
print('Total Tax in Mandalay:',mandalay['Tax 5%'].sum())
print('Gross Margin Percentage in Mandalay:',mandalay['gross margin percentage'].mean(),'%')
# Out:
# Mean of Total Rating in Mandalay: 6.8180722891566266
# Total Sales in Mandalay: 106197.67199999999
# Total Cost of Good Sold in Mandalay: 101140.64
# Total Gross Income in Mandalay: 5057.032
# Total Tax in Mandalay: 5057.032
# Gross Margin Percentage in Mandalay: 4.761904762000016 %

# %%
print('Mean of Total Rating in Naypyitaw:',naypyitaw['Rating'].mean())
print('Total Sales in Naypyitaw:',naypyitaw['Total'].sum())
print('Total Cost of Good Sold in Naypyitaw:',naypyitaw['cogs'].sum())
print('Total Gross Income in Naypyitaw:',naypyitaw['gross income'].sum())
print('Total Tax in Naypyitaw :',naypyitaw['Tax 5%'].sum())
print('Gross Margin Percentage in Naypyitaw:',naypyitaw['gross margin percentage'].mean(),'%')
# Out:
# Mean of Total Rating in Naypyitaw: 7.072865853658538
# Total Sales in Naypyitaw: 110568.7065
# Total Cost of Good Sold in Naypyitaw: 105303.53
# Total Gross Income in Naypyitaw: 5265.1765
# Total Tax in Naypyitaw : 5265.1765
# Gross Margin Percentage in Naypyitaw: 4.7619047620000154 %

# %%
fashion_y=yangon.loc[yangon['Product line']=='Fashion accessories']
food_y=yangon.loc[yangon['Product line']=='Food and beverages']
electronics_y=yangon.loc[yangon['Product line']=='Electronic accessories']
sports_y=yangon.loc[yangon['Product line']=='Sports and travel']
home_y=yangon.loc[yangon['Product line']=='Home and lifestyle']
health_y=yangon.loc[yangon['Product line']=='Health and beauty ']

# %%
fashion_m=mandalay.loc[mandalay['Product line']=='Fashion accessories']
food_m=mandalay.loc[mandalay['Product line']=='Food and beverages']
electronics_m=mandalay.loc[mandalay['Product line']=='Electronic accessories']
sports_m=mandalay.loc[mandalay['Product line']=='Sports and travel']
home_m=mandalay.loc[mandalay['Product line']=='Home and lifestyle']
health_m=mandalay.loc[mandalay['Product line']=='Health and beauty ']

# %%
fashion_n=naypyitaw.loc[naypyitaw['Product line']=='Fashion accessories']
food_n=naypyitaw.loc[naypyitaw['Product line']=='Food and beverages']
electronics_n=naypyitaw.loc[naypyitaw['Product line']=='Electronic accessories']
sports_n=naypyitaw.loc[naypyitaw['Product line']=='Sports and travel']
home_n=naypyitaw.loc[naypyitaw['Product line']=='Home and lifestyle']
health_n=naypyitaw.loc[naypyitaw['Product line']=='Health and beauty ']

# %%
print('Total Sales Quantity Naypyitaw in Fashion Accessories:',fashion_n.Quantity.sum())
print('Total Sales Quantity Naypyitaw in Food and Beverages:',food_n.Quantity.sum())
print('Total Sales Quantity Naypyitaw in Electronic Accessories :',electronics_n.Quantity.sum())
print('Total Sales Quantity Naypyitaw in Sports and Travel:',sports_n.Quantity.sum())
print('Total Sales Quantity Naypyitaw in Home and Lifestyle:',home_n.Quantity.sum())
# Out:
# Total Sales Quantity Naypyitaw in Fashion Accessories: 342
# Total Sales Quantity Naypyitaw in Food and Beverages: 369
# Total Sales Quantity Naypyitaw in Electronic Accessories : 333
# Total Sales Quantity Naypyitaw in Sports and Travel: 265
# Total Sales Quantity Naypyitaw in Home and Lifestyle: 245

# %%
print('Total Sales Quantity Mandalay in Fashion Accessories:',fashion_m.Quantity.sum())
print('Total Sales Quantity Mandalay in Food and Beverages:',food_m.Quantity.sum())
print('Total Sales Quantity Mandalay in Electronic Accessories :',electronics_m.Quantity.sum())
print('Total Sales Quantity Mandalay in Sports and Travel:',sports_m.Quantity.sum())
print('Total Sales Quantity Mandalay in Home and Lifestyle:',home_m.Quantity.sum())
# Out:
# Total Sales Quantity Mandalay in Fashion Accessories: 297
# Total Sales Quantity Mandalay in Food and Beverages: 270
# Total Sales Quantity Mandalay in Electronic Accessories : 316
# Total Sales Quantity Mandalay in Sports and Travel: 322
# Total Sales Quantity Mandalay in Home and Lifestyle: 295

# %%
print('Total Sales Quantity Yangon in Fashion Accessories:',fashion_y.Quantity.sum())
print('Total Sales Quantity Yangon in Food and Beverages:',food_y.Quantity.sum())
print('Total Sales Quantity Yangon in Electronic Accessories :',electronics_y.Quantity.sum())
print('Total Sales Quantity Yangon in Sports and Travel:',sports_y.Quantity.sum())
print('Total Sales Quantity Yangon in Home and Lifestyle:',home_y.Quantity.sum())
# Out:
# Total Sales Quantity Yangon in Fashion Accessories: 263
# Total Sales Quantity Yangon in Food and Beverages: 313
# Total Sales Quantity Yangon in Electronic Accessories : 322
# Total Sales Quantity Yangon in Sports and Travel: 333
# Total Sales Quantity Yangon in Home and Lifestyle: 371

# %% [markdown]
# ## Yangon

# %%
fig, axs = plt.subplots(2, 2, figsize=(12,6))

axs[0, 0].set_title(' Yangon Gross Income',  
             fontweight ="bold")
axs[0, 0].plot(yangon['Date'],yangon['gross income'])


axs[0, 1].set_title(' Yangon Quantity Sales',  
             fontweight ="bold")
axs[0, 1].plot(yangon['Date'],yangon['Quantity'])


axs[1, 0].set_title(' Yangon Total Sales',  
             fontweight ="bold")
axs[1, 0].plot(yangon['Date'],yangon['Total'])


axs[1, 1].set_title('Yangon Cost of Good Sold',  
             fontweight ="bold")
axs[1, 1].plot(yangon['Date'],yangon['cogs'])

plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(12,6))

axs[0, 0].set_title(' Mandalay Gross Income',  
             fontweight ="bold")
axs[0, 0].plot(mandalay['Date'],mandalay['gross income'])


axs[0, 1].set_title(' Mandalay Quantity Sales',  
             fontweight ="bold")
axs[0, 1].plot(mandalay['Date'],mandalay['Quantity'])


axs[1, 0].set_title(' Mandalay Total Sales',  
             fontweight ="bold")
axs[1, 0].plot(mandalay['Date'],mandalay['Total'])


axs[1, 1].set_title('Mandalay Cost of Good Sold',  
             fontweight ="bold")
axs[1, 1].plot(mandalay['Date'],mandalay['cogs'])

plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(12,6))

axs[0, 0].set_title('Naypyitaw Gross Income',  
             fontweight ="bold")
axs[0, 0].plot(naypyitaw['Date'],naypyitaw['gross income'])


axs[0, 1].set_title('Naypyitaw Quantity Sales',  
             fontweight ="bold")
axs[0, 1].plot(naypyitaw['Date'],naypyitaw['Quantity'])


axs[1, 0].set_title(' Naypyitaw Total Sales',  
             fontweight ="bold")
axs[1, 0].plot(naypyitaw['Date'],naypyitaw['Total'])


axs[1, 1].set_title('Naypyitaw Cost of Good Sold',  
             fontweight ="bold")
axs[1, 1].plot(naypyitaw['Date'],naypyitaw['cogs'])

plt.show()

# %%
sns.set(style='darkgrid')
fig, ax = plt.subplots(2,3, figsize=(10, 6))

sns.countplot(data=yangon, x='Payment' ,ax=ax[0][0])
ax[0, 0].set_title('Yangon Payment Method',  
             fontweight ="bold")
sns.countplot(data=yangon, x='Customer type', ax=ax[0][1])
ax[0, 1].set_title('Yangon Customer Type',  
             fontweight ="bold")
sns.countplot(data=yangon, x='Gender',  ax=ax[0][2])
ax[0, 2].set_title('Yangon Customer Gender',  
             fontweight ="bold")
plt.tight_layout()
plt.show()

# %%
sns.set(style='darkgrid')
fig, ax = plt.subplots(2,3, figsize=(10, 6))

sns.countplot(data=mandalay, x='Payment' ,ax=ax[0][0])
ax[0, 0].set_title('Mandalay Payment Method',  
             fontweight ="bold")
sns.countplot(data=mandalay, x='Customer type', ax=ax[0][1])
ax[0, 1].set_title('Mandalay Customer Type',  
             fontweight ="bold")
sns.countplot(data=mandalay, x='Gender',  ax=ax[0][2])
ax[0, 2].set_title('Mandalay Customer Gender',  
             fontweight ="bold")
plt.tight_layout()
plt.show()

# %%
sns.set(style='darkgrid')
fig, ax = plt.subplots(2,3, figsize=(10, 6))

sns.countplot(data=naypyitaw, x='Payment' ,ax=ax[0][0])
ax[0, 0].set_title('Naypyitaw Payment Method',  
             fontweight ="bold")
sns.countplot(data=naypyitaw, x='Customer type', ax=ax[0][1])
ax[0, 1].set_title('Naypyitaw Customer Type',  
             fontweight ="bold")
sns.countplot(data=naypyitaw, x='Gender',  ax=ax[0][2])
ax[0, 2].set_title('NaypyitawCustomer Gender',  
             fontweight ="bold")
plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

for column in df1.columns:
    if df1[column].dtype == np.number: continue
   
    df1[column]= df1[column].astype(str)
# Out:
# <ipython-input-195-f692c142a0f0>:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df1[column].dtype == np.number: continue

# %%
for column in df1.columns:
    if df1[column].dtype == np.number: continue
   
    df1[column] = LabelEncoder().fit_transform(df1[column])
# Out:
# <ipython-input-196-2e50ddc67bef>:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df1[column].dtype == np.number: continue

# %%
df1=df1.drop(['Invoice ID'],1)

# %%
mask = np.triu(np.ones_like(df1.corr(), dtype=bool))
plt.figure(figsize=(12,5))
sns.heatmap(df1.corr(),mask=mask)

# %%
mask = np.triu(np.ones_like(yangon.corr(), dtype=bool))
plt.figure(figsize=(12,6))
sns.heatmap(yangon.corr(),mask=mask)

# %%
mask = np.triu(np.ones_like(df1.corr(), dtype=bool))
plt.figure(figsize=(12,6))
sns.heatmap(df1.corr(),mask=mask)

# %%
mask = np.triu(np.ones_like(df1.corr(), dtype=bool))
plt.figure(figsize=(12,6))
sns.heatmap(df1.corr(),mask=mask)
